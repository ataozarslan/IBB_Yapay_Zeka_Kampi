# %% [markdown]
# # Pandas Giriş

# %% [markdown]
# Pandas veri bilimi dünyasında ismini en çok duyduğumuz kütüphanelerden biridir. Özellikle bu işlerde henüz yeniyseniz aşağıda paylaşılan linke bakmanızda oldukça büyük yarar var.
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html

# %% [markdown]
# Pandas kütüphanesinin çok kullanışlı bir çok özelliği bulunur. İşte bunlardan bazıları;
#
# - Sayısal ve sayısal olmayan verilerinde **eksik verilerin** (NaN olarak temsil edilir) kolay bir şekilde işlenmesi.
# - DataFrame objelerden sütunlar **eklenebilmesi ve silinebilmesi**.
# - Veri kümelerini toplayarak ve dönüştürerek üzerinde bölme-uygulama-birleştirme işlemleri gerçekleştirmek için verileri **gruplaması**.
# - Diğer Python ve NumPy veri yapılarındaki düzensiz, farklı şekillerde indexlenmiş verileri DataFrame nesnelerine **dönüştürmeyi kolaylaştırması**.
# - Akıllı **etiket tabanlı bölümlendirme**, **indeksleme** ve büyük veri kümelerinin **subsetlenmesi**.
# - Veri kümelerinin **birleştirebilmesi**.
# - Excel dosyalarından, veritabanlarından veri yüklemek ve ultra hızlı HDF5 formatından veri kaydetmek/yüklemek için **güçlü IO araçları** olması.

# %%
# 'Pandas' kütüphanesini 'pd' kısaltmasını kullanacak şekilde import ediyoruz (literatürde kullanılan kısaltma)
import pandas as pd
import numpy as np

# %% [markdown]
# ## Veri Seti Yükleme
#
# Pandas'a veri seti yüklemenin bir çok yolu vardır. Çalışmalarınızda kullanacağınız veri setlerini bulmak için bazı güzel kaynaklar;
#
# - http://archive.ics.uci.edu/ml/index.php
# - https://datasetsearch.research.google.com/
# - https://opendata.cityofnewyork.us/
# - https://data.world/
# - https://www.kaggle.com/datasets
# - Ve çok daha fazlası...

# %% [markdown]
# ### Census Income Veri Seti
#
# Pandas kütüphanesi bilgisayarımızda hali hazırda var olan `xlsx`, `txt`, `csv`, `json`, `sql` gibi formatlardaki verileri doğrudan okuyabildiği gibi internet aracılığıyla erişebildiğimiz veri setlerini de okumamıza olanak sağlar.

# %%
# Veriye internet üzerinden istediğim sütun isimlerine göre ulaşma
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status',
           'occupation', 'relationship', 'ethnicity', 'gender','capital_gain',
           'capital_loss', 'hours_per_week', 'country_of_origin','income']

df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', names=columns)
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship ethnicity  \
# 0            Never-married        Adm-clerical   Not-in-family     White
# 1       Married-civ-spouse     Exec-managerial         Husband     White
# 2                 Divorced   Handlers-cleaners   Not-in-family     White
# 3       Married-civ-spouse   Handlers-cleaners         Husband     Black
# 4       Married-civ-spouse      Prof-specialty            Wife     Black
# ...                    ...                 ...             ...       ...
# 32556   Married-civ-spouse        Tech-support            Wife     White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband     White
# 32558              Widowed        Adm-clerical       Unmarried     White
# 32559        Never-married        Adm-clerical       Own-child     White
# 32560   Married-civ-spouse     Exec-managerial            Wife     White
#
#         gender  capital_gain  capital_loss  hours_per_week country_of_origin  \
# 0         Male          2174             0              40     United-States
# 1         Male             0             0              13     United-States
# 2         Male             0             0              40     United-States
# 3         Male             0             0              40     United-States
# 4       Female             0             0              40              Cuba
# ...        ...           ...           ...             ...               ...
# 32556   Female             0             0              38     United-States
# 32557     Male             0             0              40     United-States
# 32558   Female             0             0              40     United-States
# 32559     Male             0             0              20     United-States
# 32560   Female         15024             0              40     United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# > **HATIRLATMA:** Veriyi incelemeye başlamadan önce ilk olarak [metadatasına](https://archive.ics.uci.edu/ml/datasets/census+income) bakmayı unutmuyoruz!

# %%
print(f'DataFrame: {type(df)}')
print(f'Series: {type(df.age)}')
print(f'NumPy Array: {type(df.age.values)}')
# Out:
# DataFrame: <class 'pandas.core.frame.DataFrame'>
# Series: <class 'pandas.core.series.Series'>
# NumPy Array: <class 'numpy.ndarray'>

# %% [markdown]
# ## Verinin İçeriğini Görüntüleme
#
# * .info()
# * .head()
# * .tail()
# * .sample()
# * .columns
# * .dtypes
# * .rename()

# %% [markdown]
# ### Info
#
# DataFrame içerisinde yer alan sütunlar, bu sütunların veri tipleri, toplam kaç adet kayıt olduğu, boş değer olup olmadığı, hafızada kapladığı alan gibi, veri setimiz hakkında genel anlamda bilgi sahibi olmamızı sağlar.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                32561 non-null  int64
#  1   workclass          32561 non-null  object
#  2   fnlwgt             32561 non-null  int64
#  3   education          32561 non-null  object
#  4   education_num      32561 non-null  int64
#  5   marital_status     32561 non-null  object
#  6   occupation         32561 non-null  object
#  7   relationship       32561 non-null  object
#  8   ethnicity          32561 non-null  object
#  9   gender             32561 non-null  object
#  10  capital_gain       32561 non-null  int64
#  11  capital_loss       32561 non-null  int64
#  12  hours_per_week     32561 non-null  int64
#  13  country_of_origin  32561 non-null  object
#  14  income             32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Head
#
# DataFrame içerisinden **baştan** başlayacak şekilde istediğimiz sayıda kayıt getirir.

# %%
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital_status          occupation    relationship ethnicity  \
# 0           Never-married        Adm-clerical   Not-in-family     White
# 1      Married-civ-spouse     Exec-managerial         Husband     White
# 2                Divorced   Handlers-cleaners   Not-in-family     White
# 3      Married-civ-spouse   Handlers-cleaners         Husband     Black
# 4      Married-civ-spouse      Prof-specialty            Wife     Black
# 5      Married-civ-spouse     Exec-managerial            Wife     White
# 6   Married-spouse-absent       Other-service   Not-in-family     Black
# 7      Married-civ-spouse     Exec-managerial         Husband     White
# 8           Never-married      Prof-specialty   Not-in-family     White
# 9      Married-civ-spouse     Exec-managerial         Husband     White
#
#     gender  capital_gain  capital_loss  hours_per_week country_of_origin  \
# 0     Male          2174             0              40     United-States
# 1     Male             0             0              13     United-States
# 2     Male             0             0              40     United-States
# 3     Male             0             0              40     United-States
# 4   Female             0             0              40              Cuba
# 5   Female             0             0              40     United-States
# 6   Female             0             0              16           Jamaica
# 7     Male             0             0              45     United-States
# 8   Female         14084             0              50     United-States
# 9     Male          5178             0              40     United-States
#
#    income
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K
# 5   <=50K
# 6   <=50K
# 7    >50K
# 8    >50K
# 9    >50K

# %% [markdown]
# ### Tail
#
# DataFrame içerisinden **sondan** başlayacak şekilde istediğimiz sayıda kayıt getirir.

# %%
df.tail(8)
# Out:
#        age      workclass  fnlwgt      education  education_num  \
# 32553   32        Private  116138        Masters             14
# 32554   53        Private  321865        Masters             14
# 32555   22        Private  310152   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32557   40        Private  154374        HS-grad              9
# 32558   58        Private  151910        HS-grad              9
# 32559   22        Private  201490        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#             marital_status          occupation    relationship  \
# 32553        Never-married        Tech-support   Not-in-family
# 32554   Married-civ-spouse     Exec-managerial         Husband
# 32555        Never-married     Protective-serv   Not-in-family
# 32556   Married-civ-spouse        Tech-support            Wife
# 32557   Married-civ-spouse   Machine-op-inspct         Husband
# 32558              Widowed        Adm-clerical       Unmarried
# 32559        Never-married        Adm-clerical       Own-child
# 32560   Married-civ-spouse     Exec-managerial            Wife
#
#                  ethnicity   gender  capital_gain  capital_loss  \
# 32553   Asian-Pac-Islander     Male             0             0
# 32554                White     Male             0             0
# 32555                White     Male             0             0
# 32556                White   Female             0             0
# 32557                White     Male             0             0
# 32558                White   Female             0             0
# 32559                White     Male             0             0
# 32560                White   Female         15024             0
#
#        hours_per_week country_of_origin  income
# 32553              11            Taiwan   <=50K
# 32554              40     United-States    >50K
# 32555              40     United-States   <=50K
# 32556              38     United-States   <=50K
# 32557              40     United-States    >50K
# 32558              40     United-States   <=50K
# 32559              20     United-States   <=50K
# 32560              40     United-States    >50K

# %% [markdown]
# ### Sample
#
# DataFrame içerisinden **rastgele** bir şekilde istediğimiz sayıda kayıt getirir.

# %%
df.sample(3, random_state=10)
# Out:
#        age   workclass  fnlwgt   education  education_num  \
# 11358   58   State-gov  123329     HS-grad              9
# 10859   23   Local-gov   23438     HS-grad              9
# 30948   41     Private  433989   Assoc-voc             11
#
#             marital_status       occupation    relationship ethnicity  \
# 11358        Never-married     Adm-clerical   Not-in-family     White
# 10859        Never-married   Prof-specialty   Not-in-family     White
# 30948   Married-civ-spouse            Sales         Husband     White
#
#         gender  capital_gain  capital_loss  hours_per_week country_of_origin  \
# 11358   Female             0             0              16     United-States
# 10859   Female             0             0              40     United-States
# 30948     Male          4386             0              60     United-States
#
#        income
# 11358   <=50K
# 10859   <=50K
# 30948    >50K

# %% [markdown]
# > **SORU:** Eğer bu kod satırını tekrardan çalıştırırsam ne olur?

# %% [markdown]
# ```python
# df.sample(8, random_state=42) # Ne işe yarıyor bu random state?
# ```

# %% [markdown]
# ### Columns
#
# DataFrame içerisindeki **sütunların adlarını** döndürür.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'ethnicity', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'country_of_origin',
#        'income'],
#       dtype='object')

# %% [markdown]
# ### Dtypes
#
# DataFrame içerisindeki her bir **sütunun veri tiplerini** döndürür.

# %%
df.dtypes
# Out:
# age                   int64
# workclass            object
# fnlwgt                int64
# education            object
# education_num         int64
# marital_status       object
# occupation           object
# relationship         object
# ethnicity            object
# gender               object
# capital_gain          int64
# capital_loss          int64
# hours_per_week        int64
# country_of_origin    object
# income               object
# dtype: object

# %% [markdown]
# ### Rename Columns
#
# DataFrame içerisinde var olan bir **sütunun ismini değiştirmek** istediğimizde kullanırız.

# %%
df.rename(columns={'country_of_origin': 'native_country'})
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship ethnicity  \
# 0            Never-married        Adm-clerical   Not-in-family     White
# 1       Married-civ-spouse     Exec-managerial         Husband     White
# 2                 Divorced   Handlers-cleaners   Not-in-family     White
# 3       Married-civ-spouse   Handlers-cleaners         Husband     Black
# 4       Married-civ-spouse      Prof-specialty            Wife     Black
# ...                    ...                 ...             ...       ...
# 32556   Married-civ-spouse        Tech-support            Wife     White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband     White
# 32558              Widowed        Adm-clerical       Unmarried     White
# 32559        Never-married        Adm-clerical       Own-child     White
# 32560   Married-civ-spouse     Exec-managerial            Wife     White
#
#         gender  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship ethnicity  \
# 0            Never-married        Adm-clerical   Not-in-family     White
# 1       Married-civ-spouse     Exec-managerial         Husband     White
# 2                 Divorced   Handlers-cleaners   Not-in-family     White
# 3       Married-civ-spouse   Handlers-cleaners         Husband     Black
# 4       Married-civ-spouse      Prof-specialty            Wife     Black
# ...                    ...                 ...             ...       ...
# 32556   Married-civ-spouse        Tech-support            Wife     White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband     White
# 32558              Widowed        Adm-clerical       Unmarried     White
# 32559        Never-married        Adm-clerical       Own-child     White
# 32560   Married-civ-spouse     Exec-managerial            Wife     White
#
#         gender  capital_gain  capital_loss  hours_per_week country_of_origin  \
# 0         Male          2174             0              40     United-States
# 1         Male             0             0              13     United-States
# 2         Male             0             0              40     United-States
# 3         Male             0             0              40     United-States
# 4       Female             0             0              40              Cuba
# ...        ...           ...           ...             ...               ...
# 32556   Female             0             0              38     United-States
# 32557     Male             0             0              40     United-States
# 32558   Female             0             0              40     United-States
# 32559     Male             0             0              20     United-States
# 32560   Female         15024             0              40     United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# > **SORU:** Yapmak istediğim değişiklik uygunlanmış görülmesine rağmen orijinal DataFrame'imi tekrardan çağırdığımda eski hali karşıma geldi, sorun ne?

# %%
df.rename(columns={'country_of_origin': 'native_country'}, inplace=True)
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship ethnicity  \
# 0            Never-married        Adm-clerical   Not-in-family     White
# 1       Married-civ-spouse     Exec-managerial         Husband     White
# 2                 Divorced   Handlers-cleaners   Not-in-family     White
# 3       Married-civ-spouse   Handlers-cleaners         Husband     Black
# 4       Married-civ-spouse      Prof-specialty            Wife     Black
# ...                    ...                 ...             ...       ...
# 32556   Married-civ-spouse        Tech-support            Wife     White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband     White
# 32558              Widowed        Adm-clerical       Unmarried     White
# 32559        Never-married        Adm-clerical       Own-child     White
# 32560   Married-civ-spouse     Exec-managerial            Wife     White
#
#         gender  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ## Veri Setine İstatistiksel Değerler
#
# * .describe()
# * .value_counts()
# * .mean()
# * .std()
# * .min()
# * .max()
# * .unique()
# * .duplicated()

# %% [markdown]
# ### Describe()
#
# DataFrame içerisinde yer alan sayısal sütunlara ait **temel istatistiksel değerleri** döndürür.

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### Value_Counts()
#
# DataFrame içerisinde belirttiğimiz sütunda yer alan değerlerden **hangisinden kaç tane** olduğunu döndürür.

# %%
df['education']
# Out:
# 0          Bachelors
# 1          Bachelors
# 2            HS-grad
# 3               11th
# 4          Bachelors
#             ...
# 32556     Assoc-acdm
# 32557        HS-grad
# 32558        HS-grad
# 32559        HS-grad
# 32560        HS-grad
# Name: education, Length: 32561, dtype: object

# %%
df.education
# Out:
# 0          Bachelors
# 1          Bachelors
# 2            HS-grad
# 3               11th
# 4          Bachelors
#             ...
# 32556     Assoc-acdm
# 32557        HS-grad
# 32558        HS-grad
# 32559        HS-grad
# 32560        HS-grad
# Name: education, Length: 32561, dtype: object

# %%
df.education.value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %% [markdown]
# ```python
# df['education'].value_counts() # Aynı çıktıya kodu bu şekilde yazarak da ulaşabiliriz.
# ```

# %% [markdown]
# ### Mean() / Std() / Min() / Max() ...

# %%
print('Aritmetik Ortalama:', df['hours_per_week'].mean())
print('Standart Sapma:', df['hours_per_week'].std())
print('Minimum:', df['hours_per_week'].min())
print('Maximum:', df['hours_per_week'].max())
# Out:
# Aritmetik Ortalama: 40.437455852092995
# Standart Sapma: 12.34742868173081
# Minimum: 1
# Maximum: 99

# %% [markdown]
# ### Unique()
#
# DataFrame içerisinde belirttiğimiz sütundaki sadece **benzersiz (eşsiz)** değerleri döndürür.

# %%
df.education.nunique()
# Out:
# 16

# %%
df.education.unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %% [markdown]
# > **SORU:** Gözümüze çarpan tuhaf bir durum var mı?

# %%
df["education"] = df.education.str.strip()

# %%
df.education.unique() # Şimdi oldu :)
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %% [markdown]
# ### Duplicated()
#
# DataFrame içerisinde eğer varsa **birbirini tekrar eden satırları** tespit etmemizi sağlar.

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %% [markdown]
# **NOT:** Eğer satırdaki tüm değerleriniz tekrar etmiyorsa, ancak yine de veri setinizde **kesinlikle aynı olmaması gereken değerler varsa**, bu durumları da `duplicated()` fonksiyonumuza subset parametresini ekleyerek tespit edebiliriz.
#
# ```python
# df.duplicated(subset=["Sütun İsimleri"]) # Aynı çıktıya kodu bu şekilde yazarak da ulaşabiliriz.
# ```

# %%
df[df.duplicated()]
# Out:
#        age          workclass  fnlwgt     education  education_num  \
# 4881    25            Private  308144     Bachelors             13
# 5104    90            Private   52386  Some-college             10
# 9171    21            Private  250051  Some-college             10
# 11631   20            Private  107658  Some-college             10
# 13084   25            Private  195994       1st-4th              2
# 15059   21            Private  243368     Preschool              1
# 17040   46            Private  173243       HS-grad              9
# 18555   30            Private  144593       HS-grad              9
# 18698   19            Private   97261       HS-grad              9
# 21318   19            Private  138153  Some-college             10
# 21490   19            Private  146679  Some-college             10
# 21875   49            Private   31267       7th-8th              4
# 22300   25            Private  195994       1st-4th              2
# 22367   44            Private  367749     Bachelors             13
# 22494   49   Self-emp-not-inc   43479  Some-college             10
# 25872   23            Private  240137       5th-6th              3
# 26313   28            Private  274679       Masters             14
# 28230   27            Private  255582       HS-grad              9
# 28522   42            Private  204235  Some-college             10
# 28846   39            Private   30916       HS-grad              9
# 29157   38            Private  207202       HS-grad              9
# 30845   46            Private  133616  Some-college             10
# 31993   19            Private  251579  Some-college             10
# 32404   35            Private  379959       HS-grad              9
#
#             marital_status          occupation    relationship  \
# 4881         Never-married        Craft-repair   Not-in-family
# 5104         Never-married       Other-service   Not-in-family
# 9171         Never-married      Prof-specialty       Own-child
# 11631        Never-married        Tech-support   Not-in-family
# 13084        Never-married     Priv-house-serv   Not-in-family
# 15059        Never-married     Farming-fishing   Not-in-family
# 17040   Married-civ-spouse        Craft-repair         Husband
# 18555        Never-married       Other-service   Not-in-family
# 18698        Never-married     Farming-fishing   Not-in-family
# 21318        Never-married        Adm-clerical       Own-child
# 21490        Never-married     Exec-managerial       Own-child
# 21875   Married-civ-spouse        Craft-repair         Husband
# 22300        Never-married     Priv-house-serv   Not-in-family
# 22367        Never-married      Prof-specialty   Not-in-family
# 22494   Married-civ-spouse        Craft-repair         Husband
# 25872        Never-married   Handlers-cleaners   Not-in-family
# 26313        Never-married      Prof-specialty   Not-in-family
# 28230        Never-married   Machine-op-inspct   Not-in-family
# 28522   Married-civ-spouse      Prof-specialty         Husband
# 28846   Married-civ-spouse        Craft-repair         Husband
# 29157   Married-civ-spouse   Machine-op-inspct         Husband
# 30845             Divorced        Adm-clerical       Unmarried
# 31993        Never-married       Other-service       Own-child
# 32404             Divorced       Other-service   Not-in-family
#
#                  ethnicity   gender  capital_gain  capital_loss  \
# 4881                 White     Male             0             0
# 5104    Asian-Pac-Islander     Male             0             0
# 9171                 White   Female             0             0
# 11631                White   Female             0             0
# 13084                White   Female             0             0
# 15059                White     Male             0             0
# 17040                White     Male             0             0
# 18555                Black     Male             0             0
# 18698                White     Male             0             0
# 21318                White   Female             0             0
# 21490                Black     Male             0             0
# 21875                White     Male             0             0
# 22300                White   Female             0             0
# 22367                White   Female             0             0
# 22494                White     Male             0             0
# 25872                White     Male             0             0
# 26313                White     Male             0             0
# 28230                White   Female             0             0
# 28522                White     Male             0             0
# 28846                White     Male             0             0
# 29157                White     Male             0             0
# 30845                White   Female             0             0
# 31993                White     Male             0             0
# 32404                White   Female             0             0
#
#        hours_per_week  native_country  income
# 4881               40          Mexico   <=50K
# 5104               35   United-States   <=50K
# 9171               10   United-States   <=50K
# 11631              10   United-States   <=50K
# 13084              40       Guatemala   <=50K
# 15059              50          Mexico   <=50K
# 17040              40   United-States   <=50K
# 18555              40               ?   <=50K
# 18698              40   United-States   <=50K
# 21318              10   United-States   <=50K
# 21490              30   United-States   <=50K
# 21875              40   United-States   <=50K
# 22300              40       Guatemala   <=50K
# 22367              45          Mexico   <=50K
# 22494              40   United-States   <=50K
# 25872              55          Mexico   <=50K
# 26313              50   United-States   <=50K
# 28230              40   United-States   <=50K
# 28522              40   United-States    >50K
# 28846              40   United-States   <=50K
# 29157              48   United-States    >50K
# 30845              40   United-States   <=50K
# 31993              14   United-States   <=50K
# 32404              40   United-States   <=50K

# %% [markdown]
# Veri setimizde birbirine tekrar eden değerler var. Bunlar bizim hiçbir zaman işimize gelmez, o yüzden onlardan kurtulalım.

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Satırları ve Sütunları Seçme

# %% [markdown]
# Burada kullanacağımız 2 temel yaklaşımımız bulunmakta,
#
# ### .loc
#
# * Satırları ve sütunları ismine göre seçer
# * **Sütun ismine göre**             `.loc[]`
#
# ### .iloc
#
# * Satırları ve sütunları index numarasına göre seçer
# * **İndex numarasına göre**  `.iloc[]`

# %%
# İndex numarasına göre satır seçme
df.iloc[3]
# Out:
# age                                53
# workclass                     Private
# fnlwgt                         234721
# education                        11th
# education_num                       7
# marital_status     Married-civ-spouse
# occupation          Handlers-cleaners
# relationship                  Husband
# ethnicity                       Black
# gender                           Male
# capital_gain                        0
# capital_loss                        0
# hours_per_week                     40
# native_country          United-States
# income                          <=50K
# Name: 3, dtype: object

# %%
# Şimdi ilk 3 satır karşımıza çıktı, aynı Python'daki index yapıları gibi :)
df.iloc[0:3]
# Out:
#    age          workclass  fnlwgt  education  education_num  \
# 0   39          State-gov   77516  Bachelors             13
# 1   50   Self-emp-not-inc   83311  Bachelors             13
# 2   38            Private  215646    HS-grad              9
#
#         marital_status          occupation    relationship ethnicity gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White   Male
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K

# %%
# Belirli bir satır aralığını seçme
df.iloc[10:15]
# Out:
#     age   workclass  fnlwgt     education  education_num       marital_status  \
# 10   37     Private  280464  Some-college             10   Married-civ-spouse
# 11   30   State-gov  141297     Bachelors             13   Married-civ-spouse
# 12   23     Private  122272     Bachelors             13        Never-married
# 13   32     Private  205019    Assoc-acdm             12        Never-married
# 14   40     Private  121772     Assoc-voc             11   Married-civ-spouse
#
#           occupation    relationship            ethnicity   gender  \
# 10   Exec-managerial         Husband                Black     Male
# 11    Prof-specialty         Husband   Asian-Pac-Islander     Male
# 12      Adm-clerical       Own-child                White   Female
# 13             Sales   Not-in-family                Black     Male
# 14      Craft-repair         Husband   Asian-Pac-Islander     Male
#
#     capital_gain  capital_loss  hours_per_week  native_country  income
# 10             0             0              80   United-States    >50K
# 11             0             0              40           India    >50K
# 12             0             0              30   United-States   <=50K
# 13             0             0              50   United-States   <=50K
# 14             0             0              40               ?    >50K

# %%
# Peki son 2 satır? Bu da aynıymış :)
df.iloc[-2:]
# Out:
#        age      workclass  fnlwgt education  education_num  \
# 32559   22        Private  201490   HS-grad              9
# 32560   52   Self-emp-inc  287927   HS-grad              9
#
#             marital_status        occupation relationship ethnicity   gender  \
# 32559        Never-married      Adm-clerical    Own-child     White     Male
# 32560   Married-civ-spouse   Exec-managerial         Wife     White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income
# 32559             0             0              20   United-States   <=50K
# 32560         15024             0              40   United-States    >50K

# %%
# 2'şer satır atlayarak tüm satırları seç ancak aynı zamanda sadece 3. ve 5. sütun arasını görmek istiyorum
df.iloc[::2, 2:5].head()
# Out:
#    fnlwgt  education  education_num
# 0   77516  Bachelors             13
# 2  215646    HS-grad              9
# 4  338409  Bachelors             13
# 6  160187        9th              5
# 8   45781    Masters             14

# %%
# .loc yapısını kullanarak satır seçme
df.loc[0:3]
# Out:
#    age          workclass  fnlwgt  education  education_num  \
# 0   39          State-gov   77516  Bachelors             13
# 1   50   Self-emp-not-inc   83311  Bachelors             13
# 2   38            Private  215646    HS-grad              9
# 3   53            Private  234721       11th              7
#
#         marital_status          occupation    relationship ethnicity gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black   Male
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K

# %% [markdown]
# > **SORU:** Neden 3 satır yerine 4 satırlık bir çıktı verdi, son satır dahil edilmiyordu diye hatırlıyorum?
#
# İşte `.iloc[]` ve `.loc[]` arasındaki fark!

# %%
df.loc[0:2, ["age","relationship","hours_per_week"]]
# Out:
#    age    relationship  hours_per_week
# 0   39   Not-in-family              40
# 1   50         Husband              13
# 2   38   Not-in-family              40

# %% [markdown]
# ## Filtreleme İşlemleri

# %% [markdown]
# Şimdi de hem cinsiyeti erkek olanları hem de yaşı 30 ile 40 arasında olanları filtrelemeye çalışalım.

# %%
df[(df.age >= 30) & (df.gender == 'Male') & (df.age <= 40)]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education_num, marital_status, occupation, relationship, ethnicity, gender, capital_gain, capital_loss, hours_per_week, native_country, income]
# Index: []

# %% [markdown]
# > **SORU:** Sorun ne? Gerçekten belirlemiş olduğumuz bu filtrelere uyan bir kaydımız yok mu?

# %%
df.gender.values
# Out:
# array([' Male', ' Male', ' Male', ..., ' Female', ' Male', ' Female'],
#       dtype=object)

# %%
df[df.gender == ' Male']
# Out:
#        age          workclass  fnlwgt     education  education_num  \
# 0       39          State-gov   77516     Bachelors             13
# 1       50   Self-emp-not-inc   83311     Bachelors             13
# 2       38            Private  215646       HS-grad              9
# 3       53            Private  234721          11th              7
# 7       52   Self-emp-not-inc  209642       HS-grad              9
# ...    ...                ...     ...           ...            ...
# 32553   32            Private  116138       Masters             14
# 32554   53            Private  321865       Masters             14
# 32555   22            Private  310152  Some-college             10
# 32557   40            Private  154374       HS-grad              9
# 32559   22            Private  201490       HS-grad              9
#
#             marital_status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 2                 Divorced   Handlers-cleaners   Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 7       Married-civ-spouse     Exec-managerial         Husband
# ...                    ...                 ...             ...
# 32553        Never-married        Tech-support   Not-in-family
# 32554   Married-civ-spouse     Exec-managerial         Husband
# 32555        Never-married     Protective-serv   Not-in-family
# 32557   Married-civ-spouse   Machine-op-inspct         Husband
# 32559        Never-married        Adm-clerical       Own-child
#
#                  ethnicity gender  capital_gain  capital_loss  hours_per_week  \
# 0                    White   Male          2174             0              40
# 1                    White   Male             0             0              13
# 2                    White   Male             0             0              40
# 3                    Black   Male             0             0              40
# 7                    White   Male             0             0              45
# ...                    ...    ...           ...           ...             ...
# 32553   Asian-Pac-Islander   Male             0             0              11
# 32554                White   Male             0             0              40
# 32555                White   Male             0             0              40
# 32557                White   Male             0             0              40
# 32559                White   Male             0             0              20
#
#        native_country  income
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3       United-States   <=50K
# 7       United-States    >50K
# ...               ...     ...
# 32553          Taiwan   <=50K
# 32554   United-States    >50K
# 32555   United-States   <=50K
# 32557   United-States    >50K
# 32559   United-States   <=50K
#
# [21775 rows x 15 columns]

# %%
# Veri seti içerisinde bulunan boşlukları kaldırma
df.gender = df.gender.str.strip()
df.gender.values
# Out:
# array(['Male', 'Male', 'Male', ..., 'Female', 'Male', 'Female'],
#       dtype=object)

# %%
df.loc[(df.age >= 30) & (df.gender == 'Male') & (df.age <= 40), ['age','gender','income']]
# Out:
#        age gender  income
# 0       39   Male   <=50K
# 2       38   Male   <=50K
# 10      37   Male    >50K
# 11      30   Male    >50K
# 13      32   Male   <=50K
# ...    ...    ...     ...
# 32532   34   Male    >50K
# 32537   30   Male   <=50K
# 32551   32   Male   <=50K
# 32553   32   Male   <=50K
# 32557   40   Male    >50K
#
# [6565 rows x 3 columns]

# %% [markdown]
# ## Boş (NaN) Değerleri Bulma

# %% [markdown]
# Aslında `df.info` fonksiyonu ile veri setimizde herhangi bir boş değer olmadığını görmüştük. Ancak yine de tekrardan kontrol edelim.

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# ethnicity         0
# gender            0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
null_df = pd.DataFrame([1, 2, 4, np.nan])
null_df
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  4.0
# 3  NaN

# %% [markdown]
# ## NaN Değerleri Silme

# %% [markdown]
# Öncelikle içerisinde boş değerler barındıran bir `DataFrame` oluşturalım.

# %%
null_df.dropna()
null_df
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  4.0
# 3  NaN

# %%
null_df.dropna(inplace=True)
null_df
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  4.0

# %% [markdown]
# ## NaN Değerleri Doldurma

# %% [markdown]
# NaN değerleri istediğimiz değerle doldurabildiğimiz gibi **istatistiksel yöntemlerden** yararlanarak da bu işlemi gerçekleştirebiliriz.

# %%
null_df.median()
# Out:
# 0    2.0
# dtype: float64

# %%
null_df.fillna(null_df.median())
null_df
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  4.0

# %%
null_df.fillna(null_df.mean(), inplace=True)
null_df
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  4.0

# %% [markdown]
# Aritmetik ortalama, mod, medyan gibi büyüklüklerle boş değerlerimizi doldurabileceğimizi görmüş olduk. Bu yaklaşım, genellikle NaN değerleri kendi belirlediğimiz bir değerle doldurmaktan daha mantıklı sonuçlar verir. **Ancak her zaman değil!**

# %% [markdown]
# ## Apply()

# %%
df.hours_per_week.describe()
# Out:
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours_per_week, dtype: float64

# %%
def study_hour(hour):
    if hour > 60:
        return 'High'
    elif hour > 30:
        return 'Medium'
    elif hour > 0:
        return "Low"
    else:
        return 'Never'

# %%
study_hour(65)
# Out:
# 'High'

# %%
study_hour(15)
# Out:
# 'Low'

# %%
df['study_hour'] = df.hours_per_week.apply(study_hour)
df
# Out:
#        age          workclass  fnlwgt   education  education_num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32556   27            Private  257302  Assoc-acdm             12
# 32557   40            Private  154374     HS-grad              9
# 32558   58            Private  151910     HS-grad              9
# 32559   22            Private  201490     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
#
#             marital_status          occupation    relationship ethnicity  \
# 0            Never-married        Adm-clerical   Not-in-family     White
# 1       Married-civ-spouse     Exec-managerial         Husband     White
# 2                 Divorced   Handlers-cleaners   Not-in-family     White
# 3       Married-civ-spouse   Handlers-cleaners         Husband     Black
# 4       Married-civ-spouse      Prof-specialty            Wife     Black
# ...                    ...                 ...             ...       ...
# 32556   Married-civ-spouse        Tech-support            Wife     White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband     White
# 32558              Widowed        Adm-clerical       Unmarried     White
# 32559        Never-married        Adm-clerical       Own-child     White
# 32560   Married-civ-spouse     Exec-managerial            Wife     White
#
#        gender  capital_gain  capital_loss  hours_per_week  native_country  \
# 0        Male          2174             0              40   United-States
# 1        Male             0             0              13   United-States
# 2        Male             0             0              40   United-States
# 3        Male             0             0              40   United-States
# 4      Female             0             0              40            Cuba
# ...       ...           ...           ...             ...             ...
# 32556  Female             0             0              38   United-States
# 32557    Male             0             0              40   United-States
# 32558  Female             0             0              40   United-States
# 32559    Male             0             0              20   United-States
# 32560  Female         15024             0              40   United-States
#
#        income study_hour
# 0       <=50K     Medium
# 1       <=50K        Low
# 2       <=50K     Medium
# 3       <=50K     Medium
# 4       <=50K     Medium
# ...       ...        ...
# 32556   <=50K     Medium
# 32557    >50K     Medium
# 32558   <=50K     Medium
# 32559   <=50K        Low
# 32560    >50K     Medium
#
# [32537 rows x 16 columns]

# %% [markdown]
# ## Map()

# %%
df.income.value_counts()
# Out:
#  <=50K    24698
#  >50K      7839
# Name: income, dtype: int64

# %%
df.income.values
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype=object)

# %%
df.income = df.income.str.strip()

# %%
income_dict = {
    '<=50K': 'Poor',
    '>50K': 'Rich'
}

# %%
df['income'] = df.income.map(income_dict)
df
# Out:
#        age          workclass  fnlwgt   education  education_num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32556   27            Private  257302  Assoc-acdm             12
# 32557   40            Private  154374     HS-grad              9
# 32558   58            Private  151910     HS-grad              9
# 32559   22            Private  201490     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
#
#             marital_status          occupation    relationship ethnicity  \
# 0            Never-married        Adm-clerical   Not-in-family     White
# 1       Married-civ-spouse     Exec-managerial         Husband     White
# 2                 Divorced   Handlers-cleaners   Not-in-family     White
# 3       Married-civ-spouse   Handlers-cleaners         Husband     Black
# 4       Married-civ-spouse      Prof-specialty            Wife     Black
# ...                    ...                 ...             ...       ...
# 32556   Married-civ-spouse        Tech-support            Wife     White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband     White
# 32558              Widowed        Adm-clerical       Unmarried     White
# 32559        Never-married        Adm-clerical       Own-child     White
# 32560   Married-civ-spouse     Exec-managerial            Wife     White
#
#        gender  capital_gain  capital_loss  hours_per_week  native_country  \
# 0        Male          2174             0              40   United-States
# 1        Male             0             0              13   United-States
# 2        Male             0             0              40   United-States
# 3        Male             0             0              40   United-States
# 4      Female             0             0              40            Cuba
# ...       ...           ...           ...             ...             ...
# 32556  Female             0             0              38   United-States
# 32557    Male             0             0              40   United-States
# 32558  Female             0             0              40   United-States
# 32559    Male             0             0              20   United-States
# 32560  Female         15024             0              40   United-States
#
#       income study_hour
# 0       Poor     Medium
# 1       Poor        Low
# 2       Poor     Medium
# 3       Poor     Medium
# 4       Poor     Medium
# ...      ...        ...
# 32556   Poor     Medium
# 32557   Rich     Medium
# 32558   Poor     Medium
# 32559   Poor        Low
# 32560   Rich     Medium
#
# [32537 rows x 16 columns]

# %% [markdown]
# ## Group By

# %% [markdown]
# Elimizdeki verilerden anlamlı bilgiler elde etmek için onları amacımıza uygun bir şekilde **gruplamak** gerekir. Bu işlemlerin `pandas` üzerinde nasıl yapıldığını inceleyelim.

# %%
# Biz bu tarz çıktıları elde etmek için value_counts() fonksiyonundan yararlanıyorduk
df.groupby('relationship').count()
# Out:
#                    age  workclass  fnlwgt  education  education_num  \
# relationship
#  Husband         13187      13187   13187      13187          13187
#  Not-in-family    8292       8292    8292       8292           8292
#  Other-relative    981        981     981        981            981
#  Own-child        5064       5064    5064       5064           5064
#  Unmarried        3445       3445    3445       3445           3445
#  Wife             1568       1568    1568       1568           1568
#
#                  marital_status  occupation  ethnicity  gender  capital_gain  \
# relationship
#  Husband                  13187       13187      13187   13187         13187
#  Not-in-family             8292        8292       8292    8292          8292
#  Other-relative             981         981        981     981           981
#  Own-child                 5064        5064       5064    5064          5064
#  Unmarried                 3445        3445       3445    3445          3445
#  Wife                      1568        1568       1568    1568          1568
#
#                  capital_loss  hours_per_week  native_country  income  \
# relationship
#  Husband                13187           13187           13187   13187
#  Not-in-family           8292            8292            8292    8292
#  Other-relative           981             981             981     981
#  Own-child               5064            5064            5064    5064
#  Unmarried               3445            3445            3445    3445
#  Wife                    1568            1568            1568    1568
#
#                  study_hour
# relationship
#  Husband              13187
#  Not-in-family         8292
#  Other-relative         981
#  Own-child             5064
#  Unmarried             3445
#  Wife                  1568

# %%
df.groupby(['education']).mean()
# Out:
#                     age         fnlwgt  education_num  capital_gain  \
# education
# 10th          37.429796  196832.465166            6.0    404.574491
# 11th          32.355745  194928.077447            7.0    215.097872
# 12th          32.000000  199097.508083            8.0    284.087760
# 1st-4th       46.397590  239824.795181            2.0    127.391566
# 5th-6th       42.945783  232425.174699            3.0    176.551205
# 7th-8th       48.444961  188322.291473            4.0    234.302326
# 9th           41.060311  202485.066148            5.0    342.089494
# Assoc-acdm    37.381443  193424.093721           12.0    640.399250
# Assoc-voc     38.553546  181936.016643           11.0    715.051375
# Bachelors     38.906594  187999.912386           13.0   1756.955726
# Doctorate     47.702179  186698.760291           16.0   4770.145278
# HS-grad       38.978178  189542.362302            9.0    577.184868
# Masters       44.059233  179797.295006           14.0   2564.051684
# Preschool     43.200000  235739.800000            1.0    916.360000
# Prof-school   44.746528  185663.706597           15.0  10414.416667
# Some-college  35.755836  188793.849355           10.0    599.564268
#
#               capital_loss  hours_per_week
# education
# 10th             56.845659       37.052519
# 11th             50.079149       33.925957
# 12th             32.337182       35.780600
# 1st-4th          48.909639       38.234940
# 5th-6th          68.457831       38.849398
# 7th-8th          65.770543       39.365891
# 9th              28.998054       38.044747
# Assoc-acdm       93.418932       40.504217
# Assoc-voc        72.754703       41.610709
# Bachelors       118.394545       42.614048
# Doctorate       262.845036       46.973366
# HS-grad          70.513627       40.574995
# Masters         166.816492       43.832753
# Preschool        67.820000       36.380000
# Prof-school     231.203125       47.425347
# Some-college     71.725625       38.868855

# %% [markdown]
# **ÖNEMLİ NOT:** `groupby` içerisine yazdığımız sütunların sıralaması önemlidir, bu sıralama yapılacak grupların sıralamasını belirler!

# %%
df.groupby(['education', 'age'])[['hours_per_week', 'capital_gain']].mean()
# Out:
#                   hours_per_week  capital_gain
# education    age
# 10th         17        21.543478    266.659420
#              18        27.894737      0.000000
#              19        34.500000      0.000000
#              20        39.400000      0.000000
#              21        39.000000    229.882353
# ...                          ...           ...
# Some-college 81        13.000000      0.000000
#              82        11.500000      0.000000
#              84        35.000000      0.000000
#              88        40.000000      0.000000
#              90        32.400000      0.000000
#
# [965 rows x 2 columns]

# %%
df.groupby(['income', 'native_country']).age.agg(['count', 'mean'])
# Out:
#                          count       mean
# income native_country
# Poor    ?                  436  36.869266
#         Cambodia            12  35.666667
#         Canada              82  41.012195
#         China               55  41.800000
#         Columbia            57  39.228070
# ...                        ...        ...
# Rich    Thailand             3  32.666667
#         Trinadad&Tobago      2  42.500000
#         United-States     7169  44.298368
#         Vietnam              5  35.400000
#         Yugoslavia           6  40.166667
#
# [82 rows x 2 columns]

# %% [markdown]
# `.agg` fonksiyonunu ekranda nasıl çıktılar görmek istiyorsak o şekilde modifiye etme şansına da sahibibiz :)

# %%
df.groupby(['income', 'native_country']).agg({'age': 'mean', 'capital_gain': 'sum'})
# Out:
#                                age  capital_gain
# income native_country
# Poor    ?                36.869266         49712
#         Cambodia         35.666667          5979
#         Canada           41.012195          9077
#         China            41.800000          5714
#         Columbia         39.228070         10656
# ...                            ...           ...
# Rich    Thailand         32.666667             0
#         Trinadad&Tobago  42.500000             0
#         United-States    44.298368      28449414
#         Vietnam          35.400000         29368
#         Yugoslavia       40.166667          5556
#
# [82 rows x 2 columns]

# %% [markdown]
# Eğer veri setinin tümüne ihtiyacımız yoksa, kendi belirlediğimiz bir grup veri içerisinde de gruplama yapabiliriz.

# %%
df[df.native_country == ' United-States'].groupby(['education']).hours_per_week.mean()
# Out:
# education
# 10th            36.915094
# 11th            33.682287
# 12th            34.950685
# 1st-4th         32.913043
# 5th-6th         36.979381
# 7th-8th         39.058233
# 9th             38.035443
# Assoc-acdm      40.656823
# Assoc-voc       41.633049
# Bachelors       42.709190
# Doctorate       47.408537
# HS-grad         40.595606
# Masters         44.165138
# Preschool       28.117647
# Prof-school     47.484064
# Some-college    38.879810
# Name: hours_per_week, dtype: float64

# %% [markdown]
# ## Sıralama İşlemleri
#
# `sort_index()` index numaralarına göre sıralama yapmamızı sağlarken, `sort_values()` elde edilen değerlere göre sıralama yapmamıza olanak tanır.

# %%
df_grouped = df.groupby(['income', 'native_country']).mean().sort_values('age', ascending=False)
df_grouped
# Out:
#                                   age         fnlwgt  education_num  \
# income native_country
# Rich    Hungary             57.333333  172137.333333      11.000000
#         Columbia            53.500000  283410.500000      15.500000
#         Scotland            52.666667  208306.666667      10.666667
#         Poland              50.583333  179314.166667      11.083333
#         Italy               50.360000  185383.360000      10.960000
# ...                               ...            ...            ...
# Poor    Guatemala           32.508475  268389.644068       6.084746
#         Holand-Netherlands  32.000000   27882.000000      10.000000
# Rich    Hong                31.500000  294478.833333      13.833333
#         Dominican-Republic  30.500000  220226.000000       9.000000
# Poor    Taiwan              29.322581  181981.290323      12.548387
#
#                             capital_gain  capital_loss  hours_per_week
# income native_country
# Rich    Hungary              1726.000000      0.000000       50.000000
#         Columbia                0.000000      0.000000       50.000000
#         Scotland             1726.000000      0.000000       46.666667
#         Poland               2743.083333      0.000000       39.000000
#         Italy                1253.040000     79.080000       45.400000
# ...                                  ...           ...             ...
# Poor    Guatemala             120.084746     27.016949       39.338983
#         Holand-Netherlands      0.000000   2205.000000       40.000000
# Rich    Hong                    0.000000    329.500000       45.000000
#         Dominican-Republic  49999.500000      0.000000       47.000000
# Poor    Taiwan                 71.032258     51.677419       33.774194
#
# [82 rows x 6 columns]

# %% [markdown]
# > **SORU:** `ascending=True` parametresini tanımlamamız sıralamada nasıl bir değişikliğe sebep oldu?

# %%
df_grouped2 = df.groupby(['income', 'native_country']).mean().sort_values('age')
df_grouped2
# Out:
#                                   age         fnlwgt  education_num  \
# income native_country
# Poor    Taiwan              29.322581  181981.290323      12.548387
# Rich    Dominican-Republic  30.500000  220226.000000       9.000000
#         Hong                31.500000  294478.833333      13.833333
# Poor    Holand-Netherlands  32.000000   27882.000000      10.000000
#         Guatemala           32.508475  268389.644068       6.084746
# ...                               ...            ...            ...
# Rich    Italy               50.360000  185383.360000      10.960000
#         Poland              50.583333  179314.166667      11.083333
#         Scotland            52.666667  208306.666667      10.666667
#         Columbia            53.500000  283410.500000      15.500000
#         Hungary             57.333333  172137.333333      11.000000
#
#                             capital_gain  capital_loss  hours_per_week
# income native_country
# Poor    Taiwan                 71.032258     51.677419       33.774194
# Rich    Dominican-Republic  49999.500000      0.000000       47.000000
#         Hong                    0.000000    329.500000       45.000000
# Poor    Holand-Netherlands      0.000000   2205.000000       40.000000
#         Guatemala             120.084746     27.016949       39.338983
# ...                                  ...           ...             ...
# Rich    Italy                1253.040000     79.080000       45.400000
#         Poland               2743.083333      0.000000       39.000000
#         Scotland             1726.000000      0.000000       46.666667
#         Columbia                0.000000      0.000000       50.000000
#         Hungary              1726.000000      0.000000       50.000000
#
# [82 rows x 6 columns]

# %% [markdown]
# - Bu da bize aynı çıktıyı vermiş gibi duruyor, nerede hata yapıyorum???

# %%
df_grouped3 = df.groupby(['income', 'native_country']).mean().sort_values('age', ascending=False)
df_grouped3
# Out:
#                                   age         fnlwgt  education_num  \
# income native_country
# Rich    Hungary             57.333333  172137.333333      11.000000
#         Columbia            53.500000  283410.500000      15.500000
#         Scotland            52.666667  208306.666667      10.666667
#         Poland              50.583333  179314.166667      11.083333
#         Italy               50.360000  185383.360000      10.960000
# ...                               ...            ...            ...
# Poor    Guatemala           32.508475  268389.644068       6.084746
#         Holand-Netherlands  32.000000   27882.000000      10.000000
# Rich    Hong                31.500000  294478.833333      13.833333
#         Dominican-Republic  30.500000  220226.000000       9.000000
# Poor    Taiwan              29.322581  181981.290323      12.548387
#
#                             capital_gain  capital_loss  hours_per_week
# income native_country
# Rich    Hungary              1726.000000      0.000000       50.000000
#         Columbia                0.000000      0.000000       50.000000
#         Scotland             1726.000000      0.000000       46.666667
#         Poland               2743.083333      0.000000       39.000000
#         Italy                1253.040000     79.080000       45.400000
# ...                                  ...           ...             ...
# Poor    Guatemala             120.084746     27.016949       39.338983
#         Holand-Netherlands      0.000000   2205.000000       40.000000
# Rich    Hong                    0.000000    329.500000       45.000000
#         Dominican-Republic  49999.500000      0.000000       47.000000
# Poor    Taiwan                 71.032258     51.677419       33.774194
#
# [82 rows x 6 columns]

# %%
df.groupby(['income','native_country']).mean().sort_values(['hours_per_week','age'], ascending=[True,False])
# Out:
#                              age         fnlwgt  education_num  capital_gain  \
# income native_country
# Poor    Hungary        47.000000  182993.800000      10.700000    413.800000
#         Taiwan         29.322581  181981.290323      12.548387     71.032258
#         Honduras       32.750000  272571.000000       8.166667      0.000000
#         Peru           35.379310  271800.517241       9.206897     63.137931
#         El-Salvador    32.649485  264114.123711       6.340206    190.773196
# ...                          ...            ...            ...           ...
# Rich    Greece         50.250000  121954.125000      11.125000   3741.250000
#         France         40.166667  172499.916667      12.666667   1116.750000
#         South          44.875000  160641.250000      11.687500   9066.937500
#         Thailand       32.666667  199784.000000      12.666667      0.000000
#         Honduras       47.000000   51835.000000      15.000000      0.000000
#
#                        capital_loss  hours_per_week
# income native_country
# Poor    Hungary          166.800000       31.300000
#         Taiwan            51.677419       33.774194
#         Honduras           0.000000       34.333333
#         Peru               0.000000       35.068966
#         El-Salvador       34.000000       36.030928
# ...                             ...             ...
# Rich    Greece           539.625000       50.625000
#         France             0.000000       50.750000
#         South            361.312500       51.437500
#         Thailand           0.000000       58.333333
#         Honduras        1902.000000       60.000000
#
# [82 rows x 6 columns]

# %% [markdown]
# Her bir `native_country` özelinde, yanında `income` değerlerini de görmek tabloyu okumayı kolaylaştırır gibi duruyor. Peki bunu nasıl yapabiliriz?

# %%
df_grouped4 = df.groupby(['income','native_country']).mean().reset_index().sort_values(['hours_per_week','age'], ascending=[True,False])
df_grouped4
# Out:
#    income native_country        age         fnlwgt  education_num  \
# 18   Poor        Hungary  47.000000  182993.800000      10.700000
# 36   Poor         Taiwan  29.322581  181981.290323      12.548387
# 16   Poor       Honduras  32.750000  272571.000000       8.166667
# 29   Poor           Peru  35.379310  271800.517241       9.206897
# 8    Poor    El-Salvador  32.649485  264114.123711       6.340206
# ..    ...            ...        ...            ...            ...
# 54   Rich         Greece  50.250000  121954.125000      11.125000
# 52   Rich         France  40.166667  172499.916667      12.666667
# 75   Rich          South  44.875000  160641.250000      11.687500
# 77   Rich       Thailand  32.666667  199784.000000      12.666667
# 57   Rich       Honduras  47.000000   51835.000000      15.000000
#
#     capital_gain  capital_loss  hours_per_week
# 18    413.800000    166.800000       31.300000
# 36     71.032258     51.677419       33.774194
# 16      0.000000      0.000000       34.333333
# 29     63.137931      0.000000       35.068966
# 8     190.773196     34.000000       36.030928
# ..           ...           ...             ...
# 54   3741.250000    539.625000       50.625000
# 52   1116.750000      0.000000       50.750000
# 75   9066.937500    361.312500       51.437500
# 77      0.000000      0.000000       58.333333
# 57      0.000000   1902.000000       60.000000
#
# [82 rows x 8 columns]

# %% [markdown]
# `reset_index()` fonksiyonu ile yaptığım gruplama sonucunda elde ettiğim tablodan kendime yeni bir `DataFrame` oluşturmuş oldum. Süper! Artık elde ettiğim bu çıktıyı istediğim her yerde kullanabilirim :)
